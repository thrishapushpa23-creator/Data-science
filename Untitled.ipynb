# %%
a=5

# %%
a=8

# %%
import numpy as np

# %%
a=[10,20,30,40]

# %%
type(a)
# Out:
# list

# %%
x = np.array(a)

# %%
print(x)
# Out:
# [10 20 30 40]

# %%
type(x)
# Out:
# numpy.ndarray

# %%
a=
